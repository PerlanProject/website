# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
from PerlanLib_basic import *

# %%
# !pwd
# Out:
# /Users/jdm/Workbench/Perlan/data_convert

# %%
rc = RCData("63.txt")
# Out:
# Flight data extracted
#   2%|▏         | 5181/231822 [00:00<00:06, 37020.86it/s]
# line corrupted:  16
# line corrupted:  22
# line corrupted:  27
# line corrupted:  32
# line corrupted:  37
# line corrupted:  43
# line corrupted:  48
# line corrupted:  53
# line corrupted:  59
# line corrupted:  64
# line corrupted:  69
# line corrupted:  75
# line corrupted:  79
# line corrupted:  86
# line corrupted:  92
# line corrupted:  98
# line corrupted:  103
# line corrupted:  109
# line corrupted:  115
# line corrupted:  122
# line corrupted:  126
# line corrupted:  306
# line corrupted:  312
# line corrupted:  318
# line corrupted:  323
# line corrupted:  329
# line corrupted:  333
# line corrupted:  340
# line corrupted:  346
# line corrupted:  649
# line corrupted:  656
# line corrupted:  664
# line corrupted:  671
# line corrupted:  677
# line corrupted:  685
# line corrupted:  692
# line corrupted:  697
# line corrupted:  913
# line corrupted:  919
# line corrupted:  927
# ...

# %%
df = rc.data
df
# Out:
#           time  lat  lon  UNR_temperature  alt imu_pitch imu_roll imu_yaw  \
# 0      51915.0  NaN  NaN            12.15  NaN       NaN      NaN     NaN
# 1      51916.0  NaN  NaN            12.05  NaN       NaN      NaN     NaN
# 2      51918.0  NaN  NaN            12.06  NaN       NaN      NaN     NaN
# 3      51919.0  NaN  NaN            12.13  NaN       NaN      NaN     NaN
# 4      51920.0  NaN  NaN            12.02  NaN       NaN      NaN     NaN
# ...        ...  ...  ...              ...  ...       ...      ...     ...
# 68842      NaN  NaN  NaN            11.97  NaN       NaN      NaN     NaN
# 68843      NaN  NaN  NaN            11.82  NaN       NaN      NaN     NaN
# 68844      NaN  NaN  NaN            11.97  NaN       NaN      NaN     NaN
# 68845      NaN  NaN  NaN            12.06  NaN       NaN      NaN     NaN
# 68846      NaN  NaN  NaN            12.09  NaN       NaN      NaN     NaN
#
#       imu_hdg imu_ias  ... imu_cl adp_ias_rc adp_alpha_rc adp_beta_rc  \
# ...

# %%
for col in df.columns:
    cnt = len(df[col].dropna())
    print(f"{col}: {cnt} non-nan")
# Out:
# time: 68621 non-nan
# lat: 24311 non-nan
# lon: 24311 non-nan
# UNR_temperature: 20317 non-nan
# alt: 24219 non-nan
# imu_pitch: 0 non-nan
# imu_roll: 0 non-nan
# imu_yaw: 0 non-nan
# imu_hdg: 0 non-nan
# imu_ias: 0 non-nan
# imu_tas: 0 non-nan
# imu_v_z: 0 non-nan
# imu_te_var: 0 non-nan
# imu_ne_var: 0 non-nan
# imu_p_pitch: 0 non-nan
# imu_fp_yaw: 0 non-nan
# imu_status: 0 non-nan
# imu_aoa: 0 non-nan
# imu_cl: 0 non-nan
# adp_ias_rc: 0 non-nan
# adp_alpha_rc: 0 non-nan
# adp_beta_rc: 0 non-nan
# imu_event_number: 0 non-nan
# aileron_left: 0 non-nan
# aileron_right: 0 non-nan
# elevator_left: 0 non-nan
# elevator_right: 0 non-nan
# rudder: 0 non-nan

# %%
df2 = df[['time','lat','lon','UNR_temperature','alt']]
df2
# Out:
#           time  lat  lon  UNR_temperature  alt
# 0      51915.0  NaN  NaN            12.15  NaN
# 1      51916.0  NaN  NaN            12.05  NaN
# 2      51918.0  NaN  NaN            12.06  NaN
# 3      51919.0  NaN  NaN            12.13  NaN
# 4      51920.0  NaN  NaN            12.02  NaN
# ...        ...  ...  ...              ...  ...
# 68842      NaN  NaN  NaN            11.97  NaN
# 68843      NaN  NaN  NaN            11.82  NaN
# 68844      NaN  NaN  NaN            11.97  NaN
# 68845      NaN  NaN  NaN            12.06  NaN
# 68846      NaN  NaN  NaN            12.09  NaN
#
# [68847 rows x 5 columns]

# %%
df2.dropna(subset=['time','lat','lon'])
# Out:
#           time        lat        lon  UNR_temperature  alt
# 1273   52954.0 -50.283695 -72.080761              NaN  NaN
# 1275   52955.0 -50.283682 -72.080731              NaN  NaN
# 1277   52956.0 -50.283665 -72.080704              NaN  NaN
# 1281   52957.0 -50.283649 -72.080683              NaN  NaN
# 1283   52958.0 -50.283644 -72.080664              NaN  NaN
# ...        ...        ...        ...              ...  ...
# 68613  78550.0 -50.283505 -72.080724              NaN  NaN
# 68614  78551.0 -50.283500 -72.080722              NaN  NaN
# 68617  78552.0 -50.283493 -72.080715              NaN  NaN
# 68619  78553.0 -50.283485 -72.080709              NaN  NaN
# 68620  78554.0 -50.283491 -72.080711              NaN  NaN
#
# [24311 rows x 5 columns]

# %%
df2.dropna(subset=['lat','UNR_temperature'])
# Out:
# Empty DataFrame
# Columns: [time, lat, lon, UNR_temperature, alt]
# Index: []

# %%
df2.dropna(subset=['UNR_temperature', 'alt'])
# Out:
# Empty DataFrame
# Columns: [time, lat, lon, UNR_temperature, alt]
# Index: []

# %%
df2.dropna(subset=['lat','alt'])
# Out:
# Empty DataFrame
# Columns: [time, lat, lon, UNR_temperature, alt]
# Index: []

# %%
xl1 = pd.read_excel("Flt65 Data.xlsx", sheet_name="Flt")

# %%
xl2 = pd.read_excel("Flt65 Data.xlsx", sheet_name="Temperatures")

# %%
xl1.columns
# Out:
# Index(['GPS Time', 'Local Time', 'Altitude (m)', 'Altitude (ft)',
#        'Cabin Differential PSI', 'Cabin Abs PSI', 'Outside Pressure PSI',
#        'Cabin Temp C', 'Cabin %RH', 'Cabin O2%', 'Front O2%', 'Rear O2%',
#        'Oxy Tank %', 'Air Tank %', 'Cabin Dew Point C', 'Cabin Alt (ft)',
#        'RTD OAT', 'Science OAT C', 'BMV Temp C', 'Batt Voltage', 'Batt1 %',
#        'Batt1 Current', 'Batt1 Temp C', 'Batt1 Heater %', 'Oxy Reg Temp C',
#        'Oxy Reg Heater %', 'Air Reg Temp C', 'Air Reg Heater %',
#        'Heater Box Temp C', 'Oxy Tank Temp C', 'Air Tank Temp C',
#        'Camera Heater Box Temp C', 'Tail Tip Temp C', 'Voltage at Tail',
#        'Ozone ppb', 'Backup Cabin O2', 'O2 Line Pressure', 'Wind Direction',
#        'Wind Speed (kph)', 'Batt2 %', 'Batt2 V', 'Batt2 Temp C',
#        'Batt2 Current', 'Batt %', 'Total Current', 'Front O2 (2) %',
#        'Rear O2 (2) %', 'Cabin CO2'],
#       dtype='object')

# %%
xl2.columns
# Out:
# Index(['GPS Time', 'Local Time', 'Cabin Temp2 C', 'Rebreather 1 Temp C',
#        'Rebreather 2 Temp C', 'Cam Heater Self Heat %',
#        'Camera 1 Temperature C', 'Camera 1 Heater %', 'Camera 2 Temperature C',
#        'Camera 2 Heater %', 'POM Temp C', 'POM Heater', 'Battery 2 Temp C',
#        'Battery 2 Heater %', 'Flutter Excitation', 'Flutter Status',
#        'Left Linear Temp', 'Right Linear Temp', 'Left Torsion Temp',
#        'Right Torsion Temp', 'POM Cell Temp C', 'UVA mW/cm2', 'UVB mW/cm2',
#        'Digital Outside Temp C', 'RTD Outside Temp C', 'Altitude M',
#        'Altitude Ft', 'Belly Cam Temp C', 'Tail Flutter Temp',
#        'Flutter Radio Temp'],
#       dtype='object')

# %%
xl1 = xl1.dropna(subset=["GPS Time", "Local Time"]).set_index(["GPS Time", "Local Time"], drop=False)

# %%
xl2 = xl2.dropna(subset=["GPS Time", "Local Time"]).set_index(["GPS Time", "Local Time"])

# %%
xl = xl1.join(xl2)

# %%
len(xl)
# Out:
# 26211

# %%
cols = list(xl.columns)
cols.sort()
cols
# Out:
# ['Air Reg Heater %',
#  'Air Reg Temp C',
#  'Air Tank %',
#  'Air Tank Temp C',
#  'Altitude (ft)',
#  'Altitude (m)',
#  'Altitude Ft',
#  'Altitude M',
#  'BMV Temp C',
#  'Backup Cabin O2',
#  'Batt %',
#  'Batt Voltage',
#  'Batt1 %',
#  'Batt1 Current',
#  'Batt1 Heater %',
#  'Batt1 Temp C',
#  'Batt2 %',
#  'Batt2 Current',
#  'Batt2 Temp C',
#  'Batt2 V',
#  'Battery 2 Heater %',
#  'Battery 2 Temp C',
#  'Belly Cam Temp C',
#  'Cabin %RH',
#  'Cabin Abs PSI',
#  'Cabin Alt (ft)',
#  'Cabin CO2',
#  'Cabin Dew Point C',
#  'Cabin Differential PSI',
#  'Cabin O2%',
#  'Cabin Temp C',
#  'Cabin Temp2 C',
#  'Cam Heater Self Heat %',
#  'Camera 1 Heater %',
#  'Camera 1 Temperature C',
#  'Camera 2 Heater %',
#  'Camera 2 Temperature C',
#  'Camera Heater Box Temp C',
#  'Digital Outside Temp C',
#  'Flutter Excitation',
#  'Flutter Radio Temp',
#  'Flutter Status',
#  'Front O2 (2) %',
#  'Front O2%',
#  'GPS Time',
#  'Heater Box Temp C',
#  'Left Linear Temp',
# ...

# %%
xl = xl.drop(columns=['Altitude Ft', 'Altitude M', 'Battery 2 Heater %', 'Battery 2 Temp C'])

# %%
xl = xl.dropna(subset=['Altitude (ft)'])
xl = xl[xl['Altitude (ft)'] >= 0.0]

# %%
xl
# Out:
#                      GPS Time Local Time  Altitude (m)  Altitude (ft)  \
# GPS Time Local Time
# 133455.0 10:34:55    133455.0   10:34:55         227.8     747.375328
# 133456.0 10:34:56    133456.0   10:34:56         228.0     748.031496
# 133457.0 10:34:57    133457.0   10:34:57         227.6     746.719160
# 133458.0 10:34:58    133458.0   10:34:58         228.1     748.359580
# 133459.0 10:34:59    133459.0   10:34:59         228.1     748.359580
# ...                       ...        ...           ...            ...
# 195314.0 16:53:14    195314.0   16:53:14         248.9     816.601050
# 195315.0 16:53:15    195315.0   16:53:15         249.2     817.585302
# 195316.0 16:53:16    195316.0   16:53:16         248.7     815.944882
# 195317.0 16:53:17    195317.0   16:53:17         249.2     817.585302
# 195318.0 16:53:18    195318.0   16:53:18         248.6     815.616798
#
#                      Cabin Differential PSI  Cabin Abs PSI  \
# GPS Time Local Time
# ...

# %%
import plotly as plt

# %%
xl["Science OAT C"].dtype
# Out:
# dtype('float64')

# %%
alt = xl['Altitude (ft)']
temp = xl['Science OAT C']

# %%
import plotly.express as px

# %%
px.scatter(xl, x='UVA mW/cm2', y='Altitude (ft)')
px.scatter(xl, x='UVB mW/cm2', y='Altitude (ft)')

# %%
xl.to_csv('flt.csv')

# %%
flts = pd.read_csv("../data/flights.csv")

# %%
flts
# Out:
#     flight_number flight_date         city airport  takeoff_time_local  \
# 0               1  2015-09-23  Redmond, OR    KRDM                 818
# 1               2  2016-01-15   Minden, NV    KMEV                1307
# 2               3  2016-01-15   Minden, NV    KMEV                1420
# 3               4  2016-01-27   Minden, NV    KMEV                1423
# 4               5  2016-01-27   Minden, NV    KMEV                1525
# ..            ...         ...          ...     ...                 ...
# 60             61  2019-08-31  El Calafate    SAWC                1037
# 61             62  2019-09-06  El Calafate    SAWC                1333
# 62             63  2019-09-11  El Calafate    SAWC                1235
# 63             64  2019-09-14  El Calafate    SAWC                 913
# 64             65  2019-09-17  El Calafate    SAWC                1120
#
#     landing_time_local  duration  release_altitude_feet  \
# 0                  851       0.6                   8100
# ...

# %%
px.scatter(flts, x='flight_number', y=['duration'])

# %%
px.scatter(flts, x=['max_alt_k', 'flight_number'], y='duration', labels=["Duration (hours)"])

# %%
flts["max_alt_k"] = flts["maximum_altitude_feet"] / 1000.0
